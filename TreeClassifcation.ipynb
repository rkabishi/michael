# %% [markdown]
# <a href="https://colab.research.google.com/github/rkabishi/michael/blob/master/TreeClassifcation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TREE

# %%
from sklearn import tree

# %%
clf_tree = tree.DecisionTreeClassifier()

X = [[181, 80, 44], [177, 70, 43], [160, 60, 38], [154, 54, 37], [166, 65, 40],
     [190, 90, 47], [175, 64, 39],
     [177, 70, 40], [159, 55, 37], [171, 75, 42], [181, 85, 43]]

Y = ['male', 'male', 'female', 'female', 'male', 'male', 'female', 'female',
     'female', 'male', 'male']

# %%
clf = clf_tree.fit(X, Y)
prediction = clf.predict([[190, 70, 43]])
print(prediction)
# Out:
# ['male']

# %% [markdown]
# #LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf_lr = LogisticRegression()
clf = clf_lr.fit(X, Y)
prediction = clf.predict([[190, 70, 43]])
print(prediction)
# Out:
# ['female']

# %% [markdown]
# # K-NEAREST NEIGHBORS(KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf_knn = KNeighborsClassifier(n_neighbors=5)
clf = clf_knn.fit(X, Y)
prediction = clf.predict([[190, 70, 43]])
print(prediction)
# Out:
# ['male']
